# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
### Loading the Dataset
data = pd.read_csv("House_Rent_Dataset.csv")

# %%
data['Tenant Preferred'].value_counts()
# Out:
# Bachelors/Family    3444
# Bachelors            830
# Family               472
# Name: Tenant Preferred, dtype: int64

# %%
data['Size'].value_counts()
# Out:
# 1000    240
# 600     225
# 800     220
# 1200    193
# 500     192
#        ...
# 2770      1
# 1252      1
# 904       1
# 721       1
# 855       1
# Name: Size, Length: 615, dtype: int64

# %%
data['Area Type'].value_counts()
# Out:
# Super Area     2446
# Carpet Area    2298
# Built Area        2
# Name: Area Type, dtype: int64

# %%
data['Furnishing Status'].value_counts()
# Out:
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: Furnishing Status, dtype: int64

# %%
data['City'].value_counts()
# Out:
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524
# Name: City, dtype: int64

# %%
data.head(10)
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
# 5  2022-04-29    2   7000   600  Ground out of 1   Super Area
# 6  2022-06-21    2  10000   700  Ground out of 4   Super Area
# 7  2022-06-21    1   5000   250       1 out of 2   Super Area
# 8  2022-06-07    2  26000   800       1 out of 2  Carpet Area
# 9  2022-06-20    2  10000  1000       1 out of 3  Carpet Area
#
#                      Area Locality     City Furnishing Status  \
# 0                           Bandel  Kolkata       Unfurnished
# 1         Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished
# 2          Salt Lake City Sector 2  Kolkata    Semi-Furnished
# ...

# %%
area = data['Size']

# %%
area
# Out:
# 0       1100
# 1        800
# 2       1000
# 3        800
# 4        850
#         ...
# 4741    1000
# 4742    2000
# 4743    1750
# 4744    1500
# 4745    1000
# Name: Size, Length: 4746, dtype: int64

# %%
area.iloc(0)

# %%
area.iloc[0]
# Out:
# 1100

# %%
rent = data['Rent']

# %%
area.size
# Out:
# 4746

# %%
area.size == rent.size
# Out:
# True

# %%
rent_per_sq_ft = []
x = 0
while x < rent.size:
    rent_per_sq_ft.append(rent.iloc[x]/area.iloc[x])
    x+=1

# %%
rent_per_sq_ft
# Out:
# [9.090909090909092,
#  25.0,
#  17.0,
#  12.5,
#  8.823529411764707,
#  11.666666666666666,
#  14.285714285714286,
#  20.0,
#  32.5,
#  10.0,
#  20.833333333333332,
#  12.5,
#  26.0,
#  14.666666666666666,
#  9.444444444444445,
#  31.104199066874028,
#  10.0,
#  12.5,
#  5.5,
#  9.090909090909092,
#  12.153846153846153,
#  22.5,
#  13.333333333333334,
#  4.0625,
#  20.0,
#  7.0,
#  14.929577464788732,
#  6.0,
#  10.625,
#  14.705882352941176,
#  21.428571428571427,
#  16.666666666666668,
#  10.909090909090908,
#  10.0,
#  20.0,
#  17.647058823529413,
#  15.625,
#  11.11111111111111,
#  23.333333333333332,
#  37.03703703703704,
#  11.428571428571429,
#  8.0,
#  8.333333333333334,
#  12.142857142857142,
#  20.0,
#  7.6923076923076925,
#  11.5,
#  18.46153846153846,
#  15.0,
#  14.044943820224718,
#  50.0,
#  16.666666666666668,
#  6.25,
#  15.0,
#  12.222222222222221,
#  11.666666666666666,
#  5.0,
#  5.0,
#  10.76923076923077,
#  11.805555555555555,
#  16.666666666666668,
#  25.0,
# ...

# %%
len(rent_per_sq_ft)
# Out:
# 4746

# %%
data['Rent per Square Feet'] = rent_per_sq_ft

# %%
data['Rent per Square Feet']
# Out:
# 0        9.090909
# 1       25.000000
# 2       17.000000
# 3       12.500000
# 4        8.823529
#           ...
# 4741    15.000000
# 4742    14.500000
# 4743    20.000000
# 4744    30.000000
# 4745    15.000000
# Name: Rent per Square Feet, Length: 4746, dtype: float64

# %%
data.head(20)
# Out:
#      Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0   2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1   2022-05-13    2  20000   800       1 out of 3   Super Area
# 2   2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3   2022-07-04    2  10000   800       1 out of 2   Super Area
# 4   2022-05-09    2   7500   850       1 out of 2  Carpet Area
# 5   2022-04-29    2   7000   600  Ground out of 1   Super Area
# 6   2022-06-21    2  10000   700  Ground out of 4   Super Area
# 7   2022-06-21    1   5000   250       1 out of 2   Super Area
# 8   2022-06-07    2  26000   800       1 out of 2  Carpet Area
# 9   2022-06-20    2  10000  1000       1 out of 3  Carpet Area
# 10  2022-05-23    3  25000  1200       1 out of 4  Carpet Area
# 11  2022-06-07    1   5000   400       1 out of 1  Carpet Area
# 12  2022-05-14    1   6500   250       1 out of 4  Carpet Area
# 13  2022-05-09    1   5500   375       1 out of 2  Carpet Area
# ...

# %%
data.sort_values('Rent')
# Out:
#        Posted On  BHK     Rent  Size            Floor    Area Type  \
# 4076  2022-05-31    3     1200  2100       1 out of 3  Carpet Area
# 285   2022-05-24    1     1500   200  Ground out of 2   Super Area
# 471   2022-05-12    1     1800   500  Ground out of 1   Super Area
# 2475  2022-06-22    2     2000    60       1 out of 1   Super Area
# 146   2022-06-05    2     2200   550       2 out of 3   Super Area
# ...          ...  ...      ...   ...              ...          ...
# 1459  2022-06-27    4   700000  3200     24 out of 24  Carpet Area
# 1329  2022-06-23    4   850000  3200       2 out of 4  Carpet Area
# 827   2022-05-18    4  1000000  3064     18 out of 45  Carpet Area
# 1001  2022-06-01    4  1200000  5000      4 out of 15  Carpet Area
# 1837  2022-06-08    3  3500000  2500       4 out of 4  Carpet Area
#
#                 Area Locality       City Furnishing Status  Tenant Preferred  \
# 4076            Uppal, NH 2 2  Hyderabad         Furnished  Bachelors/Family
# ...

# %%
data.sort_values('Rent',ascending=False)
# Out:
#        Posted On  BHK     Rent  Size            Floor    Area Type  \
# 1837  2022-06-08    3  3500000  2500       4 out of 4  Carpet Area
# 1001  2022-06-01    4  1200000  5000      4 out of 15  Carpet Area
# 827   2022-05-18    4  1000000  3064     18 out of 45  Carpet Area
# 1329  2022-06-23    4   850000  3200       2 out of 4  Carpet Area
# 1459  2022-06-27    4   700000  3200     24 out of 24  Carpet Area
# ...          ...  ...      ...   ...              ...          ...
# 146   2022-06-05    2     2200   550       2 out of 3   Super Area
# 2475  2022-06-22    2     2000    60       1 out of 1   Super Area
# 471   2022-05-12    1     1800   500  Ground out of 1   Super Area
# 285   2022-05-24    1     1500   200  Ground out of 2   Super Area
# 4076  2022-05-31    3     1200  2100       1 out of 3  Carpet Area
#
#                 Area Locality       City Furnishing Status  Tenant Preferred  \
# 1837             Marathahalli  Bangalore    Semi-Furnished         Bachelors
# ...

# %%
data.head(100)
# Out:
#      Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0   2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1   2022-05-13    2  20000   800       1 out of 3   Super Area
# 2   2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3   2022-07-04    2  10000   800       1 out of 2   Super Area
# 4   2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ..         ...  ...    ...   ...              ...          ...
# 95  2022-05-23    1   5000   300       1 out of 2  Carpet Area
# 96  2022-06-28    2  12000  1200       1 out of 3   Super Area
# 97  2022-06-23    2  10000   500       3 out of 4  Carpet Area
# 98  2022-04-29    4  18000  1200       1 out of 2   Super Area
# 99  2022-06-13    2  15000   900       1 out of 2  Carpet Area
#
#                 Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                      Bandel  Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
data.sort_values('Rent',ascending=False).head(100)
# Out:
#        Posted On  BHK     Rent  Size         Floor    Area Type  \
# 1837  2022-06-08    3  3500000  2500    4 out of 4  Carpet Area
# 1001  2022-06-01    4  1200000  5000   4 out of 15  Carpet Area
# 827   2022-05-18    4  1000000  3064  18 out of 45  Carpet Area
# 1329  2022-06-23    4   850000  3200    2 out of 4  Carpet Area
# 1459  2022-06-27    4   700000  3200  24 out of 24  Carpet Area
# ...          ...  ...      ...   ...           ...          ...
# 1391  2022-07-09    4   210000  2000  27 out of 27  Carpet Area
# 595   2022-06-24    2   210000  1000    4 out of 8  Carpet Area
# 634   2022-05-18    4   210000  1783   5 out of 20  Carpet Area
# 1388  2022-06-16    3   210000  1425   9 out of 35  Carpet Area
# 2990  2022-07-10    3   200000  3000    1 out of 1   Super Area
#
#                            Area Locality       City Furnishing Status  \
# 1837                        Marathahalli  Bangalore    Semi-Furnished
# ...

# %%
data.head(10)
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
# 5  2022-04-29    2   7000   600  Ground out of 1   Super Area
# 6  2022-06-21    2  10000   700  Ground out of 4   Super Area
# 7  2022-06-21    1   5000   250       1 out of 2   Super Area
# 8  2022-06-07    2  26000   800       1 out of 2  Carpet Area
# 9  2022-06-20    2  10000  1000       1 out of 3  Carpet Area
#
#                      Area Locality     City Furnishing Status  \
# 0                           Bandel  Kolkata       Unfurnished
# 1         Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished
# 2          Salt Lake City Sector 2  Kolkata    Semi-Furnished
# ...

# %%
data['City'].value_counts()
# Out:
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524
# Name: City, dtype: int64

# %%
data['Floor'].value_counts()
# Out:
# 1 out of 2         379
# Ground out of 2    350
# 2 out of 3         312
# 2 out of 4         308
# 1 out of 3         293
#                   ...
# 11 out of 31         1
# 50 out of 75         1
# 18 out of 26         1
# 12 out of 27         1
# 23 out of 34         1
# Name: Floor, Length: 480, dtype: int64

# %%
plt.bar(data['Floor'].value_counts().index, data['Floor'].value_counts().values)
# Out:
# <BarContainer object of 480 artists>

# %%
data['Area Locality'].value_counts()
# Out:
# Bandra West                                37
# Gachibowli                                 29
# Electronic City                            24
# Velachery                                  22
# Miyapur, NH 9                              22
#                                            ..
# Kengeri Upanagara                           1
# Ittamadu, Banashankari, Outer Ring Road     1
# Rmv Extension, Armane Nagar                 1
# snv la                                      1
# Manikonda, Hyderabad                        1
# Name: Area Locality, Length: 2235, dtype: int64
